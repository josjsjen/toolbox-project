# %% [markdown]
# <img src='https://s3.amazonaws.com/weclouddata/images/logos/wcd_logo.png' width='50%'>
# -------------
#
# <h1 align='center'> Eventbrite API </h1>
# <h2 align='center'> Working with Web APIs </h2>
#
# <br>
# <center align="left"> Designed by: </center>
# <center align="left"> WeCloudData Academy </center>
#
#
# ----------

# %% [markdown]
# ### Installation
# $ pip install eventbrite
#
#
# ### Eventbrite API Documentation
# > https://www.eventbrite.com/developer/v3/

# %%
from eventbrite import Eventbrite

# %% [markdown]
# ### Event parsing functions

# %%
def parse_eventname(events_response):
    eventnames = [e['name']['text'] for e in events_response['events']]
    return eventnames

def parse_event(events_response):
    parsed_events = [(e['created'], 
                      e['name']['text'], 
                      e['organizer_id'], 
                      e['venue_id'],
                      e['is_free']) for e in events_response['events']]
    return parsed_events

# %% [markdown]
# # $\Delta$ 1. Get Events

# %% [markdown]
# ### $\Omega$ Example: Events and Pagination

# %%
eventbrite.get("https://www.eventbriteapi.com/v3/users/me/")
# Out:
# {'emails': [{'email': 'wecloud@weclouddata.com',
#    'primary': True,
#    'verified': False}],
#  'first_name': 'Rong',
#  'id': '175508455052',
#  'image_id': '26909870',
#  'is_public': False,
#  'last_name': 'Li',
#  'name': 'Rong Li'}

# %%
eventbrite = Eventbrite('OI3G4HL23XZBW2RCUWAS') 
response = eventbrite.get("/users/me/owned_events")
response['pagination']
# Out:
# {'continuation': 'eyJwYWdlIjogMn0',
#  'has_more_items': True,
#  'object_count': 156,
#  'page_count': 4,
#  'page_number': 1,
#  'page_size': 50}

# %% [markdown]
# ### $\Omega$ Example: Get the names of all the events you have created in the past

# %%
eventnames = []
continuation = ''
while True:
    response = eventbrite.get("/users/me/owned_events/?continuation=" + continuation)
    eventnames.extend(parse_eventname(response))
    if not response['pagination']['has_more_items']:
        break
    else:
        continuation = response['pagination']['continuation']

# %%
eventnames
# Out:
# ["SAS Analytics in Real World - Experts' Experience Sharing",
#  'SAS Base/Advanced Programming Course',
#  'Python for Data Science - The Why, What & How',
#  'Python for Data Science - The Why, What & How',
#  'SAS Base & Advance Programming Course',
#  'Open Class: Python for Data Science - The Why, What & How',
#  'Open Class: Python for Data Science - The Why, What & How',
#  'Open Class: Python for Data Science - The Why, What & How',
#  'Big Data Info Session－Free Use Case Sharing',
#  'Big Data Info Session－Free Use Case Sharing',
#  "Big Data Foundation Open Class - It's Free!",
#  'Free Workshop - Big Data Real World Solution',
#  'Free Workshop - Big Data Real World Solution',
#  'Building Enterprise Big Data Lake 【Free Trial】',
#  'Real-Time Bidding -Free Big Data Use Case Sharing Series',
#  'Real-time Bidding - FREE Big Data and Machine Learning Workshop Series 2',
#  'Big Data Foundation FREE TRIAL',
#  'Python for Data Science - Use Case Sharing',
#  'Python for Data Science - Use Case Sharing',
#  'Python for Data Science Free Open Class',
#  'Landing Data Scientist Jobs – The Secret Sauce',
#  'Big Data Foundation Fast Track Info Session',
#  'Big Data Real World Solution —— An Introduction to Big Data Fast Track',
#  "SAS Analytics in Real World - Experts' Experience Sharing",
#  'SAS Programming FREE Workshop',
#  "SAS Analytics in Real World - Experts' Experience Sharing",
#  'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#  'Course Info Session: Python for Data Science with FREE Real-world Use Case Sharing',
#  'Workshop - Python for Data Science',
#  'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#  'Data Analytics SAS Use Case Sharing ',
#  'Machine Learning Course Information Session',
#  'FREE Open Class - Building Enterprise Big Data Lake ',
#  'Machine Learning and Big Data Foundation Info Session with FREE Use Case Sharing',
#  'Python for Data Science Free Open Class',
#  'Machine Learning Course Info Session',
#  'Landing Data Scientist Jobs – The Secret Sauce',
#  'Course Info Session - Big Data Foundation',
#  'Big Data Foundation FREE TRIAL',
#  'Quantitative Analysis Application in Financial Risk Management',
#  'Quantitative Analysis Application in Financial Risk Management ',
#  'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#  'Quantitative Analysis Application in Financial Risk Management FREE Open Class',
#  'Machine Learning Use Case Sharing ',
#  'Data Science Toolbox Free Trial- Python Hands-on Labs ',
#  'Machine Learning Use Case Sharing & Information Session',
#  'Data Science Toolbox - Linux Hands-on Labs',
#  'Machine Learning Open Class',
#  'Machine Learning & Data Science ',
#  'Data Science Toolbox Info Session',
#  'A Day in the Life of a Data Scientist',
#  'Data Science Toolbox Info Session',
#  'Course Information Session: Python for Data Science',
#  'Quantitative Analysis Application in Financial Risk Management ',
#  'Free SAS Workshop & Information Session for Marketing Analytics and Risk Management',
#  'Python for Data Science Information Session - The Why, What & How',
#  'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#  'Python for Data Science Free Open Class',
#  'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#  'Business Analytics - Marketing Analysis and Risk Management',
#  'Free Open Class - Marketing and Customer Analytics',
#  'Python for Data Science Free Open Class',
#  'FREE Open Class - Building Enterprise Big Data Lake ',
#  'Free Open Class - Quantitative Risk Management, Business Intelligence and Predictive Modelling',
#  'Free Webinar - Big Data Foundation',
#  'Free Webinar - Data Science Toolbox Information Session',
#  'Data Science at Scale - Big Data Foundation FREE TRIAL I',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science Toolbox Info Session',
#  '2-day Data Science Bootcamp in Toronto',
#  'Information Session - "Data Science Toolbox"',
#  'Big Data Foundation Open Class II',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science at Scale - Big Data Foundation',
#  'Information Session - "Data Science Toolbox"',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science at Scale - Big Data Foundation',
#  'Free workshop - Introduction to Machine Learning and Live Demo',
#  'Data Science at Scale - Big Data Foundation',
#  'Data Science at Scale - Big Data Foundation',
#  'Open Class I - Machine Learning ',
#  'Machine Learning Industry Overview and Career Path',
#  'Python for Data Science Information Session',
#  'Data Science at Scale - Big Data Foundation',
#  'Open Class II - Machine Learning ',
#  'Free Open Class - Python for Data Science ',
#  'Data Science at Scale - Big Data Foundation',
#  'Free Open Class II - Python for Data Science ',
#  'Data Science at Scale - Big Data Foundation',
#  'Free workshop - "Required Tools for a Data Scientist"',
#  'Interview Tips: What Hiring Managers Really Want from You',
#  "Data Scientists' Toolbox Information Session",
#  'Becoming Business Analyst - Industry Landscape and Career Path',
#  'Information Session - Data Science Fast Track',
#  'Becoming Business Analyst - Industry Landscape and Career Path',
#  'Introduction to Data Science Capstone Projects',
#  'Introduction to Data Science Capstone Projects - How to build a reactive machine learning system from scratch',
#  'Learn How the Best Make Data Science Work for Business',
#  'Information Session - Quantitative Risk Management and Business Analytics',
#  'Free Workshop - Quantitative Risk Management, Business Intelligence and Predictive Modelling',
#  'Big Data Info Session－Free Use Case Sharing',
#  'Python for Data Science - Use Case Sharing',
#  'The Canadian Job Market of Data Engineering',
#  'Financial Risk Management FREE Open Class',
#  "Big Data Foundation Open Class - It's Free!",
#  "Information Session - Data Scientists' Toolbox",
#  'FREE Open Class - Building Enterprise Big Data Lake ',
#  'WCD Campus Tour | Land Your First Data Scientist Job (McMaster)',
#  'WCD Campus Tour | Land Your First Data Scientist Job (Western)',
#  'Free Python for Data Science Open Class - Introduction to Data Science and Numpy',
#  'WCD Campus Tour | Land Your First Data Scientist Job (U of T St. George)',
#  'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#  'WCD Campus Tour | Land Your First Data Scientist Job (Western)',
#  "Free Workshop - Data Engineering Canada's Industry Landscape and Free Use Case Sharing",
#  'WCD Campus Tour | Land Your First Data Scientist Job (U of T Mississauga)',
#  'Free Python for Data Science Open Class - Introduction to Numpy',
#  'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#  'FREE Open Class - Building Enterprise Big Data Lake ',
#  "Data Scientists' Toolbox Information Session",
#  'FREE Machine Learning Info Session - Industry Overview and Career Path',
#  'Free Big Data Open Class',
#  'Free Hands-on Workshop - SQL and its Application in Business Analytics',
#  'Free Business Analytics Workshop II - Excel and VBA in Wealth Management',
#  'Open Class I - Machine Learning ',
#  'Use Case Demo - Data Visualization by Tableau in Banking Industry',
#  'Open Class II - Machine Learning ',
#  'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#  'Everything you need to know about getting a job in data science!',
#  'How to accelerate data science learning for career switch',
#  'Python for Data Science Info Session - The What, Why & How',
#  'Machine Learning Open Class',
#  'Data Science Career Panel Discussion - What Hiring Managers Want From You',
#  "Data Scientists' Toolbox Information Session",
#  'Data Science Immersive Bootcamp Open Class',
#  'Big Data Info Session－Free Use Case Sharing',
#  'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#  'Python for Data Science Info Session - The What, Why & How',
#  'Free Python for Data Science Open Class - Introduction to Numpy',
#  'IoT and Computer Vision - A First Step towards Smart Retail Space',
#  "Data Science at Scale Open Class - It's Free!",
#  'WCD Campus Tour | Panel Discussion - Ask Whatever You Want to Know About Data Science',
#  'WCD Campus Tour | Panel Discussion - Answer Whatever You Want to Know About Data Science and Data Analytics',
#  'Panel Discussion (UTSG) - Everything You Want to Know About Data Science/Data Analytics',
#  'Data Science Toolbox Info Session',
#  'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#  'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#  'Data Science Toolbox Info Session',
#  'WCD Campus Tour | Panel Discussion - Answer Whatever You Want to Know About Data Science (Ryerson)',
#  'Data Science Toolbox Info Session',
#  'Data Analytics Career Track Information Session - EXCEL/VBA/TABLEAU',
#  'Copy of Data Analytics Career Track Information Session - SAS/SQL',
#  'Data Analytics Career Track Information Session - SAS/SQL',
#  'Data Science Toolbox Info Session',
#  'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist']

# %% [markdown]
# ### $\Omega$ Example: Sort the list of the events by created date

# %%
events = []
continuation = ''
while True:
    response = eventbrite.get("/users/me/owned_events/?continuation=" + continuation)
    events.extend(parse_event(response))
    if not response['pagination']['has_more_items']:
        break
    else:
        continuation = response['pagination']['continuation']

# %%
sorted(events, key=lambda x: x[0])
# Out:
# [('2016-05-08T04:42:20Z',
#   "SAS Analytics in Real World - Experts' Experience Sharing",
#   '10764923651',
#   '15470007',
#   True),
#  ('2016-06-13T02:24:02Z',
#   'SAS Base/Advanced Programming Course',
#   '10764923651',
#   '15720219',
#   True),
#  ('2016-06-20T17:18:07Z',
#   'Python for Data Science - The Why, What & How',
#   '10764923651',
#   '15804335',
#   True),
#  ('2016-06-22T17:16:18Z',
#   'SAS Base & Advance Programming Course',
#   '10764923651',
#   '15818841',
#   True),
#  ('2016-06-27T00:12:53Z',
#   'Python for Data Science - The Why, What & How',
#   '10764923651',
#   '15905609',
#   True),
#  ('2016-07-15T17:36:07Z',
#   'Open Class: Python for Data Science - The Why, What & How',
#   '10764923651',
#   '15804335',
#   True),
#  ('2016-07-15T17:36:07Z',
#   'Open Class: Python for Data Science - The Why, What & How',
#   '10764923651',
#   '15804335',
#   True),
#  ('2016-07-15T17:36:07Z',
#   'Open Class: Python for Data Science - The Why, What & How',
#   '10764923651',
#   '15804335',
#   True),
#  ('2016-07-16T13:59:47Z',
#   'Big Data Info Session－Free Use Case Sharing',
#   '10764923651',
#   '16174379',
#   True),
#  ('2016-07-23T02:56:07Z',
#   'Big Data Info Session－Free Use Case Sharing',
#   '10764923651',
#   '16199899',
#   True),
#  ('2016-08-12T00:19:49Z',
#   "Big Data Foundation Open Class - It's Free!",
#   '10764923651',
#   '16280243',
#   True),
#  ('2016-08-20T03:23:35Z',
#   'Free Workshop - Big Data Real World Solution',
#   '10764923651',
#   '16364410',
#   True),
#  ('2016-08-25T04:22:19Z',
#   'Free Workshop - Big Data Real World Solution',
#   '10764923651',
#   '16464824',
#   True),
#  ('2016-09-09T22:02:10Z',
#   'Building Enterprise Big Data Lake 【Free Trial】',
#   '10764923651',
#   '15410050',
#   True),
#  ('2016-09-14T21:51:44Z',
#   'Real-Time Bidding -Free Big Data Use Case Sharing Series',
#   '10764923651',
#   '16755964',
#   True),
#  ('2016-09-16T15:40:16Z',
#   'Real-time Bidding - FREE Big Data and Machine Learning Workshop Series 2',
#   '10764923651',
#   '16822088',
#   True),
#  ('2016-10-01T14:22:36Z',
#   'Big Data Foundation FREE TRIAL',
#   '10764923651',
#   '16957740',
#   True),
#  ('2016-10-12T22:28:52Z',
#   'Python for Data Science - Use Case Sharing',
#   '10764923651',
#   '17006743',
#   True),
#  ('2016-10-12T22:36:56Z',
#   'Python for Data Science - Use Case Sharing',
#   '10764923651',
#   '17173950',
#   True),
#  ('2016-10-19T20:34:13Z',
#   'Big Data Foundation Fast Track Info Session',
#   '10764923651',
#   None,
#   True),
#  ('2016-11-03T12:43:55Z',
#   'Big Data Real World Solution —— An Introduction to Big Data Fast Track',
#   '10764923651',
#   '16199899',
#   True),
#  ('2016-11-03T12:50:18Z',
#   'Python for Data Science Free Open Class',
#   '10764923651',
#   '16415625',
#   True),
#  ('2016-11-05T03:55:30Z',
#   'Landing Data Scientist Jobs – The Secret Sauce',
#   '10764923651',
#   '17279693',
#   True),
#  ('2016-11-28T23:17:26Z',
#   "SAS Analytics in Real World - Experts' Experience Sharing",
#   '10764923651',
#   '17653760',
#   True),
#  ('2016-12-03T05:20:48Z',
#   'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#   '10764923651',
#   '16415625',
#   True),
#  ('2016-12-27T16:32:40Z',
#   'Course Info Session: Python for Data Science with FREE Real-world Use Case Sharing',
#   '10764923651',
#   '17780875',
#   True),
#  ('2016-12-29T18:25:47Z',
#   'Workshop - Python for Data Science',
#   '10764923651',
#   '15246009',
#   False),
#  ('2016-12-29T18:47:30Z',
#   'Machine Learning Course Information Session',
#   '10764923651',
#   '15246009',
#   True),
#  ('2016-12-29T19:00:24Z',
#   'Machine Learning Course Info Session',
#   '10764923651',
#   '16174357',
#   True),
#  ('2016-12-29T19:04:18Z',
#   'SAS Programming FREE Workshop',
#   '10764923651',
#   '16174357',
#   True),
#  ('2016-12-29T19:05:40Z',
#   "SAS Analytics in Real World - Experts' Experience Sharing",
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-01-17T15:29:41Z',
#   'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#   '10764923651',
#   '18110251',
#   True),
#  ('2017-01-17T17:58:52Z',
#   'Data Analytics SAS Use Case Sharing ',
#   '10764923651',
#   '17653760',
#   True),
#  ('2017-01-24T04:52:15Z',
#   'Machine Learning and Big Data Foundation Info Session with FREE Use Case Sharing',
#   '10764923651',
#   '17653760',
#   True),
#  ('2017-01-24T05:09:48Z',
#   'Python for Data Science Free Open Class',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-01-31T06:03:10Z',
#   'FREE Open Class - Building Enterprise Big Data Lake ',
#   '10764923651',
#   '18162700',
#   True),
#  ('2017-01-31T16:56:16Z',
#   'Landing Data Scientist Jobs – The Secret Sauce',
#   '10764923651',
#   '18205968',
#   True),
#  ('2017-01-31T20:11:39Z',
#   'Quantitative Analysis Application in Financial Risk Management',
#   '10764923651',
#   '17653760',
#   True),
#  ('2017-02-05T18:00:16Z',
#   'Course Info Session - Big Data Foundation',
#   '10764923651',
#   '18236279',
#   True),
#  ('2017-02-14T04:57:33Z',
#   'Big Data Foundation FREE TRIAL',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-02-14T19:57:13Z',
#   'Machine Learning Use Case Sharing ',
#   '10764923651',
#   '18507378',
#   True),
#  ('2017-02-14T20:55:49Z',
#   'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#   '10764923651',
#   '18507346',
#   True),
#  ('2017-02-20T21:37:06Z',
#   'Quantitative Analysis Application in Financial Risk Management ',
#   '10764923651',
#   '18444211',
#   True),
#  ('2017-02-27T16:30:07Z',
#   'Quantitative Analysis Application in Financial Risk Management FREE Open Class',
#   '10764923651',
#   '18537314',
#   True),
#  ('2017-03-04T04:31:22Z',
#   'Machine Learning Use Case Sharing & Information Session',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-03-04T04:39:43Z',
#   'Machine Learning Open Class',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-03-10T05:32:19Z',
#   'Data Science Toolbox Free Trial- Python Hands-on Labs ',
#   '10764923651',
#   '18711362',
#   True),
#  ('2017-03-10T05:37:35Z',
#   'Data Science Toolbox - Linux Hands-on Labs',
#   '10764923651',
#   '18711362',
#   True),
#  ('2017-03-22T04:03:08Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '17653760',
#   True),
#  ('2017-03-28T18:54:37Z',
#   'Machine Learning & Data Science ',
#   '10764923651',
#   '18976903',
#   True),
#  ('2017-04-01T22:53:37Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   None,
#   True),
#  ('2017-04-05T15:17:02Z',
#   'A Day in the Life of a Data Scientist',
#   '10764923651',
#   '19086962',
#   True),
#  ('2017-04-11T15:46:31Z',
#   'Course Information Session: Python for Data Science',
#   '10764923651',
#   None,
#   True),
#  ('2017-04-18T16:23:51Z',
#   'Python for Data Science Information Session - The Why, What & How',
#   '10764923651',
#   '19391840',
#   True),
#  ('2017-04-18T17:16:59Z',
#   'Free SAS Workshop & Information Session for Marketing Analytics and Risk Management',
#   '10764923651',
#   '19334355',
#   True),
#  ('2017-04-19T03:49:58Z',
#   'Python for Data Science Free Open Class',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-04-23T18:54:54Z',
#   'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#   '10764923651',
#   None,
#   True),
#  ('2017-04-23T18:58:00Z',
#   'Course Info Session - Building Enterprise Big Data Lake with Free Use Case Sharing',
#   '10764923651',
#   '19526856',
#   True),
#  ('2017-04-23T19:03:04Z',
#   'FREE Open Class - Building Enterprise Big Data Lake ',
#   '10764923651',
#   '18162700',
#   True),
#  ('2017-04-25T02:56:28Z',
#   'Quantitative Analysis Application in Financial Risk Management ',
#   '10764923651',
#   '18444211',
#   True),
#  ('2017-04-29T01:18:56Z',
#   'Business Analytics - Marketing Analysis and Risk Management',
#   '10764923651',
#   '18537314',
#   True),
#  ('2017-04-30T12:12:20Z',
#   'Python for Data Science Free Open Class',
#   '10764923651',
#   '16174357',
#   True),
#  ('2017-05-08T21:56:26Z',
#   'Free Open Class - Marketing and Customer Analytics',
#   '10764923651',
#   '19530838',
#   True),
#  ('2017-05-08T22:10:04Z',
#   'Free Open Class - Quantitative Risk Management, Business Intelligence and Predictive Modelling',
#   '10764923651',
#   '19530838',
#   True),
#  ('2017-05-11T23:33:56Z',
#   'Data Science at Scale - Big Data Foundation FREE TRIAL I',
#   '10764923651',
#   '19936719',
#   True),
#  ('2017-05-11T23:37:17Z',
#   'Free Webinar - Big Data Foundation',
#   '10764923651',
#   None,
#   True),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-16T03:10:14Z',
#   'Data Science at Scale - Big Data Foundation',
#   '10764923651',
#   '19530838',
#   False),
#  ('2017-05-20T18:52:34Z',
#   'Free Webinar - Data Science Toolbox Information Session',
#   '10764923651',
#   None,
#   True),
#  ('2017-05-20T18:58:40Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '17653760',
#   True),
#  ('2017-05-25T19:40:40Z',
#   '2-day Data Science Bootcamp in Toronto',
#   '10764923651',
#   '19765287',
#   True),
#  ('2017-05-28T21:06:20Z',
#   'Big Data Foundation Open Class II',
#   '10764923651',
#   '19530838',
#   True),
#  ('2017-05-29T18:53:27Z',
#   'Information Session - "Data Science Toolbox"',
#   '10764923651',
#   '19801730',
#   True),
#  ('2017-06-16T15:42:41Z',
#   'Information Session - "Data Science Toolbox"',
#   '10764923651',
#   '19801730',
#   True),
#  ('2017-06-25T20:41:12Z',
#   'Open Class I - Machine Learning ',
#   '10764923651',
#   '20127967',
#   True),
#  ('2017-06-25T20:45:25Z',
#   'Open Class II - Machine Learning ',
#   '10764923651',
#   '20127970',
#   True),
#  ('2017-06-25T20:53:43Z',
#   'Free workshop - Introduction to Machine Learning and Live Demo',
#   '10764923651',
#   '20127998',
#   True),
#  ('2017-07-08T17:18:17Z',
#   'Python for Data Science Information Session',
#   '10764923651',
#   '20273650',
#   True),
#  ('2017-07-16T20:50:44Z',
#   'Free Open Class - Python for Data Science ',
#   '10764923651',
#   '20364573',
#   True),
#  ('2017-08-07T14:45:45Z',
#   'Machine Learning Industry Overview and Career Path',
#   '10764923651',
#   '20127970',
#   True),
#  ('2017-08-09T20:55:56Z',
#   'Free Open Class II - Python for Data Science ',
#   '10764923651',
#   '20364573',
#   True),
#  ('2017-08-14T23:47:51Z',
#   'Free workshop - "Required Tools for a Data Scientist"',
#   '10764923651',
#   '19801730',
#   True),
#  ('2017-08-21T19:34:44Z',
#   'Interview Tips: What Hiring Managers Really Want from You',
#   '10764923651',
#   '20814107',
#   True),
#  ('2017-08-21T19:39:59Z',
#   "Data Scientists' Toolbox Information Session",
#   '10764923651',
#   '20814107',
#   True),
#  ('2017-08-21T19:42:25Z',
#   'Becoming Business Analyst - Industry Landscape and Career Path',
#   '10764923651',
#   '21034111',
#   True),
#  ('2017-09-15T02:04:09Z',
#   'Information Session - Data Science Fast Track',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-09-15T02:08:57Z',
#   'Becoming Business Analyst - Industry Landscape and Career Path',
#   '10764923651',
#   '21034111',
#   True),
#  ('2017-09-15T12:26:07Z',
#   'Introduction to Data Science Capstone Projects',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-08T15:56:18Z',
#   'Introduction to Data Science Capstone Projects - How to build a reactive machine learning system from scratch',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-08T16:32:58Z',
#   'Learn How the Best Make Data Science Work for Business',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-08T16:38:27Z',
#   'Information Session - Quantitative Risk Management and Business Analytics',
#   '10764923651',
#   '21661561',
#   True),
#  ('2017-10-08T16:43:45Z',
#   "Free Workshop - Data Engineering Canada's Industry Landscape and Free Use Case Sharing",
#   '10764923651',
#   '19526856',
#   True),
#  ('2017-10-18T18:35:34Z',
#   'Free Workshop - Quantitative Risk Management, Business Intelligence and Predictive Modelling',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-18T18:40:03Z',
#   'Big Data Info Session－Free Use Case Sharing',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-18T18:42:02Z',
#   'Python for Data Science - Use Case Sharing',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-18T18:44:02Z',
#   'The Canadian Job Market of Data Engineering',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-20T21:22:26Z',
#   'WCD Campus Tour | Panel Discussion - Ask Whatever You Want to Know About Data Science',
#   '10764923651',
#   '23707928',
#   True),
#  ('2017-10-20T23:27:24Z',
#   'WCD Campus Tour | Land Your First Data Scientist Job (McMaster)',
#   '10764923651',
#   '21836894',
#   True),
#  ('2017-10-20T23:29:45Z',
#   'WCD Campus Tour | Land Your First Data Scientist Job (U of T St. George)',
#   '10764923651',
#   '21941772',
#   True),
#  ('2017-10-23T18:59:33Z',
#   'WCD Campus Tour | Land Your First Data Scientist Job (Western)',
#   '10764923651',
#   '21738331',
#   True),
#  ('2017-10-23T19:05:03Z',
#   'WCD Campus Tour | Land Your First Data Scientist Job (Western)',
#   '10764923651',
#   '21940423',
#   True),
#  ('2017-10-23T19:06:31Z',
#   'WCD Campus Tour | Land Your First Data Scientist Job (U of T Mississauga)',
#   '10764923651',
#   '21836930',
#   True),
#  ('2017-10-29T16:14:02Z',
#   "Information Session - Data Scientists' Toolbox",
#   '10764923651',
#   '20364573',
#   True),
#  ('2017-10-29T16:17:02Z',
#   "Big Data Foundation Open Class - It's Free!",
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-30T12:58:43Z',
#   'Financial Risk Management FREE Open Class',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-10-30T13:03:28Z',
#   'FREE Open Class - Building Enterprise Big Data Lake ',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-06T15:19:27Z',
#   'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-06T15:40:11Z',
#   'Free Python for Data Science Open Class - Introduction to Data Science and Numpy',
#   '10764923651',
#   '20364573',
#   True),
#  ('2017-11-07T20:35:11Z',
#   'FREE Open Class - Building Enterprise Big Data Lake ',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-09T16:52:03Z',
#   'FREE Machine Learning Info Session - Industry Overview and Career Path',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-13T22:42:41Z',
#   "Data Scientists' Toolbox Information Session",
#   '10764923651',
#   '20814107',
#   True),
#  ('2017-11-13T22:45:30Z',
#   'Free Python for Data Science Open Class - Introduction to Numpy',
#   '10764923651',
#   '20364573',
#   True),
#  ('2017-11-13T22:46:53Z',
#   'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-14T00:36:58Z',
#   'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-14T00:39:30Z',
#   'Free Big Data Open Class',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-11-14T00:53:05Z',
#   'Open Class I - Machine Learning ',
#   '10764923651',
#   '20127967',
#   True),
#  ('2017-11-14T01:27:14Z',
#   'Open Class II - Machine Learning ',
#   '10764923651',
#   '20127970',
#   True),
#  ('2017-11-22T22:15:24Z',
#   'Free Business Analytics Workshop II - Excel and VBA in Wealth Management',
#   '10764923651',
#   '22287821',
#   True),
#  ('2017-11-25T18:49:02Z',
#   'Free Hands-on Workshop - SQL and its Application in Business Analytics',
#   '10764923651',
#   '22287821',
#   True),
#  ('2017-11-25T19:16:44Z',
#   'Use Case Demo - Data Visualization by Tableau in Banking Industry',
#   '10764923651',
#   '22287821',
#   True),
#  ('2017-12-27T16:14:02Z',
#   'Everything you need to know about getting a job in data science!',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-12-27T16:15:48Z',
#   'How to accelerate data science learning for career switch',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-12-27T16:18:45Z',
#   'Data Science Career Panel Discussion - What Hiring Managers Want From You',
#   '10764923651',
#   '22885838',
#   True),
#  ('2017-12-27T16:36:03Z',
#   'Data Science Immersive Bootcamp Open Class',
#   '10764923651',
#   '21164442',
#   True),
#  ('2017-12-27T18:09:47Z',
#   'Python for Data Science Info Session - The What, Why & How',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-01-07T19:32:57Z',
#   'Machine Learning Open Class',
#   '10764923651',
#   '22712723',
#   True),
#  ('2018-01-12T14:53:29Z',
#   "Data Scientists' Toolbox Information Session",
#   '10764923651',
#   '20814107',
#   True),
#  ('2018-01-30T16:59:20Z',
#   'Big Data Info Session－Free Use Case Sharing',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-02-06T16:20:00Z',
#   'Free Big Data Open Class - Getting Started with Apache Spark on AWS',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-02-06T16:45:47Z',
#   'Free Python for Data Science Open Class - Introduction to Numpy',
#   '10764923651',
#   '20364573',
#   True),
#  ('2018-02-06T17:33:48Z',
#   'Python for Data Science Info Session - The What, Why & How',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-02-20T15:08:41Z',
#   'IoT and Computer Vision - A First Step towards Smart Retail Space',
#   '10764923651',
#   '23378651',
#   True),
#  ('2018-02-26T15:49:37Z',
#   "Data Science at Scale Open Class - It's Free!",
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-03-01T16:23:08Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-03-01T21:51:26Z',
#   'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-03-12T23:06:35Z',
#   'WCD Campus Tour | Panel Discussion - Answer Whatever You Want to Know About Data Science and Data Analytics',
#   '10764923651',
#   '23707928',
#   True),
#  ('2018-03-13T13:23:08Z',
#   'Panel Discussion (UTSG) - Everything You Want to Know About Data Science/Data Analytics',
#   '10764923651',
#   '23719746',
#   True),
#  ('2018-03-13T21:30:11Z',
#   'WCD Campus Tour | Panel Discussion - Answer Whatever You Want to Know About Data Science (Ryerson)',
#   '10764923651',
#   '23731285',
#   True),
#  ('2018-03-17T18:36:46Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-03-20T14:23:00Z',
#   'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-03-20T14:24:05Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-04-25T00:36:14Z',
#   'Data Analytics Career Track Information Session - EXCEL/VBA/TABLEAU',
#   '10764923651',
#   '19936719',
#   True),
#  ('2018-04-26T21:22:25Z',
#   'Data Analytics Career Track Information Session - SAS/SQL',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-04-28T15:30:50Z',
#   'Data Science Toolbox Info Session',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-04-28T15:36:31Z',
#   'Data Science Toolbox Free Information Session- Your Express Way to a Future Data Scientist',
#   '10764923651',
#   '21164442',
#   True),
#  ('2018-05-07T18:26:12Z',
#   'Copy of Data Analytics Career Track Information Session - SAS/SQL',
#   '10764923651',
#   '21164442',
#   True)]

# %% [markdown]
# ### $\Omega$ Use URL Request instead
# > An alternative way to get the data from the eventbrite API using requests

# %%
import requests
response = requests.get(
    "https://www.eventbriteapi.com/v3/users/me/owned_events/",
    headers = {
        "Authorization": "Bearer OI3G4HL23XZBW2RCUWAS",
    },
    verify = True,  # Verify SSL certificate
)
re = response.json()

# %% [markdown]
# ### $\Omega$ Get Tickets Sold Data

# %%
eventbrite.get_event_ticket_classes('44368976804')
# Out:
# {'pagination': {'has_more_items': False,
#   'object_count': 1,
#   'page_count': 1,
#   'page_number': 1,
#   'page_size': 50},
#  'ticket_classes': [{'auto_hide': False,
#    'description': None,
#    'donation': False,
#    'event_id': '44368976804',
#    'free': True,
#    'has_pdf_ticket': True,
#    'hidden': False,
#    'hide_description': True,
#    'id': '83507754',
#    'include_fee': False,
#    'maximum_quantity': 1,
#    'maximum_quantity_per_order': 0,
#    'maximum_quantity_per_order_without_pending': 0,
#    'minimum_quantity': 1,
#    'name': 'RSVP',
#    'on_sale_status': 'UNAVAILABLE',
#    'quantity_sold': 6,
#    'quantity_total': 150,
#    'resource_uri': 'https://www.eventbriteapi.com/v3/events/44368976804/ticket_classes/83507754/',
#    'sales_channels': ['online', 'atd'],
#    'sales_end': '2018-03-31T22:00:00Z',
#    'sales_start': '2017-03-22T00:55:00Z',
#    'split_fee': False,
#    'variants': []}]}

# %% [markdown]
# # $\Delta$ 2. Events Search

# %% [markdown]
# ### $\Omega$ Search for events within 10km

# %%
eventbrite = Eventbrite('OI3G4HL23XZBW2RCUWAS') 
response = eventbrite.get("/events/search/?q=data+science,location.within=10km")

# %%
response['pagination']
# Out:
# {'has_more_items': True,
#  'object_count': 78,
#  'page_count': 2,
#  'page_number': 1,
#  'page_size': 50}

# %%
response['events'][0]
# Out:
# {'capacity': 50,
#  'capacity_is_custom': True,
#  'category_id': '101',
#  'changed': '2018-05-11T01:11:18Z',
#  'created': '2018-01-12T21:57:21Z',
#  'currency': 'USD',
#  'description': {'html': '<P CLASS="MsoNormal"><STRONG>Course Description:</STRONG> Be the leader your data team needs! You have heard of data science and big data, but how do you maximize the talent you manage to leverage their value and solve complex business challenges with innovative data-driven solutions? Designed to provide managers with an understanding of how to define data science projects, the course provides an overview of data science tools and techniques, and gives guidance on managing/communicating with a team of data scientists. In this course, learn how to assemble, evaluate, and develop a data science enterprise, even if you have never worked in data science. There are no expectations participants in this course should master the technical information themselves. You will become conversant in the field and design strategies for supporting your team’s data science projects. We present this course with a focus on managing your team and moving it forward. This course is taught in once a week two hour blocks via live video by two highly experienced NCSU computer science faculty. We also have the ability to deliver this course at a client or offsite location in 1.5 days.</P>\n<P CLASS="MsoListParagraphCxSpFirst"><STRONG>Course Goal and Scope:\xa0</STRONG>\xa0This five (5) session class develops a participant\'s ability to articulate strategy with analytics specialists through a common taxonomy, clearly define and drive outcomes, and lead/manage an analytics workforce. The course covers fundamental concepts and principles underlying data science using practical, hands-on approach. The methodology spans the entire spectrum of the end-to-end data science within the Prescriptive Action Model (PAM) including:</P>\n<UL>\n<LI><I>A gentle tour of R commander</I></LI>\n<LI><I>Analytics Taxonomy</I></LI>\n<LI><I>Analytics Done Right: common mistakes and ways to avoid them</I></LI>\n<LI><I>KPI: Key Performance Indicators framework</I></LI>\n<LI><I>PAM: Prescriptive Action Model</I></LI>\n<LI>These fundamental concepts are featured through a set of business use-cases. Analytic pipelines for solving such use cases will be introduced from the end-to-end, practical, hands-on perspective using the R commander.</LI>\n</UL>\n<P CLASS="MsoNormal"><STRONG>Prerequisite(s)</STRONG>:\xa0 None</P>\n<P><STRONG>Course Dates/Times:</STRONG>\xa0The five (5) two-hour vrtual classes will be held on Thursdays from 9:00-11:00am\xa0on the following dates:</P>\n<UL>\n<LI>May 10, 2018</LI>\n<LI>May 17, 2018</LI>\n<LI>May 24, 2018</LI>\n<LI>May 31, 2018</LI>\n<LI>June 7, 2018</LI>\n<LI>June 14, 2018 (Report Out)</LI>\n</UL>\n<P CLASS="MsoNormal"><BR></P>',
#   'text': "Course Description: Be the leader your data team needs! You have heard of data science and big data, but how do you maximize the talent you manage to leverage their value and solve complex business challenges with innovative data-driven solutions? Designed to provide managers with an understanding of how to define data science projects, the course provides an overview of data science tools and techniques, and gives guidance on managing/communicating with a team of data scientists. In this course, learn how to assemble, evaluate, and develop a data science enterprise, even if you have never worked in data science. There are no expectations participants in this course should master the technical information themselves. You will become conversant in the field and design strategies for supporting your team’s data science projects. We present this course with a focus on managing your team and moving it forward. This course is taught in once a week two hour blocks via live video by two highly experienced NCSU computer science faculty. We also have the ability to deliver this course at a client or offsite location in 1.5 days.\nCourse Goal and Scope:\xa0\xa0This five (5) session class develops a participant's ability to articulate strategy with analytics specialists through a common taxonomy, clearly define and drive outcomes, and lead/manage an analytics workforce. The course covers fundamental concepts and principles underlying data science using practical, hands-on approach. The methodology spans the entire spectrum of the end-to-end data science within the Prescriptive Action Model (PAM) including:\n\nA gentle tour of R commander\nAnalytics Taxonomy\nAnalytics Done Right: common mistakes and ways to avoid them\nKPI: Key Performance Indicators framework\nPAM: Prescriptive Action Model\nThese fundamental concepts are featured through a set of business use-cases. Analytic pipelines for solving such use cases will be introduced from the end-to-end, practical, hands-on perspective using the R commander.\n\nPrerequisite(s):\xa0 None\nCourse Dates/Times:\xa0The five (5) two-hour vrtual classes will be held on Thursdays from 9:00-11:00am\xa0on the following dates:\n\nMay 10, 2018\nMay 17, 2018\nMay 24, 2018\nMay 31, 2018\nJune 7, 2018\nJune 14, 2018 (Report Out)\n\n"},
#  'end': {'local': '2018-06-14T22:00:00',
#   'timezone': 'America/New_York',
#   'utc': '2018-06-15T02:00:00Z'},
#  'format_id': '9',
#  'hide_end_date': True,
#  'hide_start_date': True,
#  'id': '42139915622',
#  'is_free': False,
#  'is_locked': False,
#  'is_reserved_seating': False,
#  'is_series': False,
#  'is_series_parent': False,
#  'listed': True,
#  'locale': 'en_US',
#  'logo': {'aspect_ratio': '2',
#   'crop_mask': {'height': 2000, 'top_left': {'x': 0, 'y': 667}, 'width': 4000},
#   'edge_color': '#7c7b7c',
#   'edge_color_set': True,
#   'id': '39787397',
#   'original': {'height': 2667,
#    'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F39787397%2F52564092914%2F1%2Foriginal.jpg?auto=compress&s=524fe2260f64d4616756820670214939',
#    'width': 4000},
#   'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F39787397%2F52564092914%2F1%2Foriginal.jpg?h=200&w=450&auto=compress&rect=0%2C667%2C4000%2C2000&s=0f1fd7f0071a8cbf0fcca24502a7bc2b'},
#  'logo_id': '39787397',
#  'name': {'html': 'Data Science for Leaders',
#   'text': 'Data Science for Leaders'},
#  'online_event': False,
#  'organization_id': '52564092914',
#  'organizer_id': '9456628244',
#  'privacy_setting': 'unlocked',
#  'resource_uri': 'https://www.eventbriteapi.com/v3/events/42139915622/',
#  'shareable': True,
#  'show_colors_in_seatmap_thumbnail': False,
#  'show_pick_a_seat': False,
#  'show_seatmap_thumbnail': False,
#  'source': 'create_2.0',
#  'start': {'local': '2018-05-10T19:00:00',
#   'timezone': 'America/New_York',
#   'utc': '2018-05-10T23:00:00Z'},
#  'status': 'started',
#  'subcategory_id': None,
#  'tx_time_limit': 480,
#  'url': 'https://www.eventbrite.com/e/data-science-for-leaders-tickets-42139915622?aff=ebapi',
#  'venue_id': '22801596',
#  'version': '3.0.0'}

# %%
events_10km_nearme = parse_event(response)

# %%
events_10km_nearme
# Out:
# [('2018-01-12T21:57:21Z',
#   'Data Science for Leaders',
#   '9456628244',
#   '22801596',
#   False),
#  ('2018-03-01T15:22:56Z',
#   'Recent Advancements in Optometry and Vision Science Congress (pgr) A',
#   '15032446657',
#   '23527389',
#   False),
#  ('2018-01-28T01:23:21Z',
#   'Best Practices in Earth Science: Meteorology',
#   '3148482172',
#   '23013457',
#   False),
#  ('2018-02-21T22:15:35Z',
#   'World Congress on Advances in Addiction Science and Medicine (pgr) A',
#   '15032446657',
#   '23250470',
#   False),
#  ('2018-04-09T14:21:40Z',
#   'The Importance of Quality Data to Close the Deal ',
#   '7946124216',
#   '13730116',
#   False),
#  ('2018-04-27T14:52:36Z',
#   '8th International Conference on Polymer Science and Engineering (CSE) AS',
#   '15032446657',
#   '22015615',
#   False),
#  ('2018-05-05T07:35:04Z',
#   ' 19th World Congress on  Materials Science and Engineering (cse) S',
#   '15032446657',
#   '24639163',
#   False),
#  ('2018-05-01T10:53:01Z',
#   ' 4th International Conference on Enzymology, Lipid Science & Glycobiology (CSE) S',
#   '15032446657',
#   '24554315',
#   False),
#  ('2018-04-26T15:08:51Z',
#   '10th International Conference on  Clinical and Medical Case Reports (cse)',
#   '15032446657',
#   '24482366',
#   False),
#  ('2018-04-05T15:51:39Z',
#   '10th Euro-Global Conference on  Infectious Diseases (cse) A',
#   '15032446657',
#   '24098812',
#   False),
#  ('2018-01-26T14:44:44Z',
#   'Accelerate AI 2018 - The ODSC Europe Business Summit',
#   '10634331863',
#   '21541282',
#   False),
#  ('2018-04-16T15:00:01Z', 'JASMIN 2018', '10719012507', '24375745', True),
#  ('2018-04-30T19:37:46Z',
#   '30 Lifetime "On-Demand" R and Research Methods Certificate Courses',
#   '10830753255',
#   None,
#   False),
#  ('2018-05-01T14:07:30Z',
#   '4th Glycobiology World Congress (CSE) S',
#   '15032446657',
#   '24557142',
#   False),
#  ('2018-01-19T10:24:31Z',
#   'SAP Autism at Work Info Session für Bewerber',
#   '16554159602',
#   '23270742',
#   True),
#  ('2018-04-19T18:27:05Z',
#   'Berlin Bootstrappers Vol. 7: No Money and No Plan',
#   '15985223735',
#   '23495806',
#   True),
#  ('2018-03-04T19:32:24Z',
#   '2nd Annual Minesing Wetlands BioBlitz!',
#   '7634744711',
#   '23569913',
#   True),
#  ('2018-03-30T22:21:42Z', 'Ketofest 2018', '17143989712', '24004663', False),
#  ('2018-05-05T15:29:45Z',
#   '4th International Conference and Exhibition on Satellite & Space Missions (cse) S',
#   '15032446657',
#   '24476320',
#   False),
#  ('2018-04-26T13:38:16Z',
#   'New Frontiers in Ocular Therapeutics 2: Moving Towards the Clinic',
#   '17257462500',
#   '24480454',
#   False),
#  ('2018-05-11T15:19:31Z',
#   '13th International Conference on  Biopharma and Biotherapeutics (cse) A',
#   '15032446657',
#   '23967143',
#   False),
#  ('2018-04-26T15:24:46Z',
#   ' 6th Global Summit on Artificial Intelligence and Neural Networks (CSE) AS',
#   '15032446657',
#   '24482387',
#   False),
#  ('2018-05-07T22:11:52Z',
#   '22nd World Congress on  Biotechnology (cse) S',
#   '15032446657',
#   '24658096',
#   False),
#  ('2018-05-10T17:54:19Z',
#   'Galvanize San Francisco: JavaScript Basic Training ',
#   '7898856643',
#   '24003717',
#   False),
#  ('2017-12-18T22:49:45Z',
#   'Essential counselling skills for working in the AOD sector (2 day workshop) 26th June & 27th June 2018',
#   '8430074318',
#   '22456432',
#   True),
#  ('2018-03-13T20:52:23Z',
#   '[Beerse, BE] The Road to the Clinic for Small Molecule',
#   '10938851684',
#   '23676593',
#   False),
#  ('2017-10-12T03:59:06Z',
#   'Cultural appreciation: Working with ATSI clients and families (Workshop #03) ',
#   '8430074318',
#   '21597415',
#   False),
#  ('2017-10-31T08:45:16Z',
#   '3IF CONFERENCE 2018: Industrial Internet, IoT & Digital Transformation for Industry',
#   '12722621274',
#   '21877207',
#   True),
#  ('2018-04-18T21:17:28Z',
#   'Designed Interactions: Diverse Perspectives',
#   '13508594844',
#   '19210190',
#   False),
#  ('2018-04-30T04:27:38Z',
#   '6th International Conference on Oceanography, Ocean Technology and Marine Biology (CSE) AS',
#   '15032446657',
#   '24520699',
#   False),
#  ('2018-03-08T03:26:18Z',
#   'EHRs for the Delivery of Quality Patient Care',
#   '17005908865',
#   '23640920',
#   False),
#  ('2018-04-06T23:16:45Z',
#   'Transportation Sector SIG Second Quarter Meeting',
#   '699435011',
#   '24494331',
#   True),
#  ('2018-01-26T02:09:39Z',
#   'Chemistry I Modeling Workshop',
#   '3148482172',
#   '22890446',
#   False),
#  ('2018-04-24T16:25:05Z',
#   '5th World Congress and Expo on  Green Energy (cse) S',
#   '15032446657',
#   '24440278',
#   False),
#  ('2018-04-23T07:09:44Z',
#   ' 9th International Conference on Global Warming and Pollution (CSE)',
#   '15032446657',
#   '24406177',
#   False),
#  ('2017-11-08T21:20:09Z',
#   'Food Safety & High-Throughput Sequencing (HTS) What Does the Future Hold?',
#   '935763813',
#   '15671694',
#   False),
#  ('2018-05-04T05:56:58Z',
#   '1st Australian Winter School (Sydney): Contaminated Site Assessment, Management and Communication ',
#   '2405475278',
#   '24621434',
#   False),
#  ('2018-05-04T06:03:16Z',
#   '1st Australian Winter School (Melbourne): Contaminated Site Assessment, Management and Communication ',
#   '2405475278',
#   '24621448',
#   False),
#  ('2018-03-02T22:26:17Z',
#   'Meet with...5AM Ventures',
#   '2487775374',
#   '15844467',
#   False),
#  ('2018-05-02T15:57:36Z',
#   '16th International Pharmaceutical Microbiology and Biotechnology Conference (cse)',
#   '15032446657',
#   '24583692',
#   False),
#  ('2018-01-09T20:10:11Z',
#   'Physics/Mechanics Modeling Workshop',
#   '3148482172',
#   '23251191',
#   False),
#  ('2017-12-13T15:03:18Z',
#   '#U2B2018 - University2Business',
#   '16009504519',
#   '23247546',
#   True),
#  ('2018-04-24T11:18:01Z',
#   'Current Regulatory Expectations for Compliant IT Infrastructure Platforms',
#   '8072365764',
#   '24431973',
#   False),
#  ('2018-04-25T15:29:10Z',
#   '3rd International Conference on  Molecular Biology & Nucleic Acids (cse)',
#   '15032446657',
#   '24460964',
#   False),
#  ('2018-03-05T15:37:40Z',
#   'World Biotechnology Congress (pgr) A',
#   '15032446657',
#   '23548272',
#   False),
#  ('2018-04-19T15:52:56Z',
#   'Annual Biotechnology Congress (cse) S',
#   '15032446657',
#   '24359911',
#   False),
#  ('2018-04-26T05:36:22Z',
#   ' 2nd Annual Congress on Environmental Pollution and Health Hazards (CSE) S',
#   '15032446657',
#   '24474774',
#   False),
#  ('2018-02-22T14:33:51Z',
#   '13th International Conference on Clinical Gastroenterology & Hepatology (pgr) A',
#   '15032446657',
#   '23385752',
#   False),
#  ('2018-04-24T22:48:49Z',
#   ' International Conference on Analytical and Bio analytical Techniques (CSE) AS',
#   '15032446657',
#   '24448991',
#   False),
#  ('2018-04-25T05:26:55Z',
#   ' 7th International Conference on Medical and Nursing Education (CSE) AS',
#   '15032446657',
#   '24452666',
#   False)]

# %% [markdown]
# ### $\Omega$ Get locations (from venue api) of all events within 10km
#
# Map visualization is done using python folium library
# > $ pip install folium

# %%
eventbrite = Eventbrite('OI3G4HL23XZBW2RCUWAS') 
response = eventbrite.get("/events/search/?q=data,location.address=toronto,location.within=10km")
events_10km_nearme = parse_event(response)

# %%
def get_location(venue_id):
    venue = eventbrite.get("/venues/" + venue_id)
    city = venue['address']['city']
    latitude = venue['address']['latitude']
    longitude = venue['address']['longitude']
    return (city, float(latitude), float(longitude))

# %%
locs = [get_location(event[3]) for event in events_10km_nearme if event[3]]
loc_events_10km_nearme = [[loc[1], loc[2]] for loc in locs]

# %%
loc_events_10km_nearme
# Out:
# [[43.6331119, -79.47091549999999],
#  [43.6427235, -79.37412219999999],
#  [43.66686370000001, -79.39048459999998],
#  [55.8735412, -4.289058399999931],
#  [51.27892319999999, 1.083193499999993],
#  [43.6504716, -79.70221520000001],
#  [43.653226, -79.38318429999998],
#  [43.6504716, -79.70221520000001],
#  [43.6426971, -79.4269046],
#  [43.6524469, -79.4490849],
#  [0.0, 0.0],
#  [-37.8143646, 144.99974270000007],
#  [53.48752349999999, -2.290126399999963],
#  [51.4919588, -0.22009560000003603],
#  [51.50262, -0.21721500000001015],
#  [-37.8254, 144.9978],
#  [52.636545, -1.6912495000000263],
#  [52.636545, -1.6912495000000263],
#  [52.636545, -1.6912495000000263],
#  [39.1281222, -84.5161329],
#  [43.6594558, -79.3895508],
#  [-37.8143646, 144.99974270000007],
#  [41.90270080000001, 12.496235200000001],
#  [-37.8143646, 144.99974270000007],
#  [45.0190505, -93.25570529999999],
#  [0.0, 0.0],
#  [51.5073509, -0.12775829999998223],
#  [43.68011449999999, -79.35767650000003],
#  [-37.8143646, 144.99974270000007],
#  [53.3091808, -6.233706999999981],
#  [52.99420120000001, -0.40561969999998837],
#  [53.21023530000001, -0.11417549999998755],
#  [53.1574429, -0.2205480999999736],
#  [-33.8426839, 151.2439961],
#  [0.0, 0.0],
#  [0.0, 0.0],
#  [-37.8143646, 144.99974270000007],
#  [43.653226, -79.38318429999998],
#  [43.7070821, -79.39761320000002],
#  [43.6504716, -79.70221520000001],
#  [41.82292100000001, 12.412110999999982],
#  [35.9940329, -78.898619],
#  [-28.416667, 153.33333300000004],
#  [30.0079141, -90.24164250000001],
#  [-33.8819116, 151.20942020000007],
#  [-37.8112953, 144.96782099999996],
#  [40.7905327, -73.97129860000001],
#  [39.21267960000001, -76.6721614]]

# %%
import folium

map = folium.Map(location=[43.65, -79.43], zoom_start=12)

for point in loc_events_10km_nearme:
    folium.Marker(point).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
